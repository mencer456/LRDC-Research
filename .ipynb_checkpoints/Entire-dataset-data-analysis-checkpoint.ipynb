# %% [markdown]
# # Data Analysis for entire dataset

# %%
#importing libaries
# %matplotlib inline
import numpy as np              
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student_info=pd.read_csv('corpus-files\student_information.csv')
course=pd.read_csv('corpus-files\course.csv')
answer_df=pd.read_csv('answer.csv',index_col = 'answer_id', low_memory=False)

# %%
course_=course.drop(columns=['class_id','semester','section'])

student=student_info.drop(columns=['birth_year','language_used_at_home','non_native_language_1','yrs_of_study_lang1',
                                  'study_in_classroom_lang1','ways_of_study_lang1','non_native_language_2','study_in_classroom_lang2',
                                  'ways_of_study_lang2','non_native_language_3','yrs_of_study_lang3','study_in_classroom_lang3',
                                  'ways_of_study_lang3','yrs_of_english_learning','yrs_in_english_environment','yrs_of_study_lang2'])
answer_=answer_df[['question_id','anon_id','course_id','version','text_len','text','tokens']].reset_index()

# %%
#This function removes all of the rows that contain a string in the passed column
def rmStr (df, col):
    row_index=0
    row_ind=[]
    for i in df[col]:
        try:
            int(i)
        except:
            row_ind.append(row_index)
        row_index+=1
    return df.drop(labels=row_ind,axis=0)

# %%
#Cleaning the answer df
col='course_id'
answer=rmStr(answer_, col) #removes strings from answer_.course_id
# Out:
#       answer_id question_id anon_id course_id version text_len  \
# 0             1           5     eq0       149       1      177
# 1             2           5     am8       149       1      137
# 2             3          12     dk5       115       1       63
# 3             4          13     dk5       115       1        6
# 4             5          12     ad1       115       1       59
# ...         ...         ...     ...       ...     ...      ...
# 46312     48416        6139     dr8      1050       1      439
# 46313     48417        6137     fv1      1045       1      478
# 46314     48418        6137     fo1      1045       1      408
# 46315     48419        6119     ge8      1033       1      110
# 46316     48420        6027     ge8      1033       1       97
#
#                                                     text  \
# 0      I met my friend Nife while I was studying in a...
# 1      Ten years ago, I met a women on the train betw...
# 2      In my country we usually don't use tea bags. F...
# 3                  I organized the instructions by time.
# 4      First, prepare a port, loose tea, and cup.\nSe...
# ...                                                  ...
# 46312  Many people enjoy a game in their free time. B...
# 46313   \n Marijuana Legalization 7/22/12\n Writing 4...
# 46314   Some patients are suffering from their illnes...
# 46315  My house looks amazing and modern. I decorated...
# 46316   History and Geography aopsule\n\n My copsule ...
#
#                                                   tokens
# 0      ['I', 'met', 'my', 'friend', 'Nife', 'while', ...
# 1      ['Ten', 'years', 'ago', ',', 'I', 'met', 'a', ...
# 2      ['In', 'my', 'country', 'we', 'usually', 'do',...
# 3      ['I', 'organized', 'the', 'instructions', 'by'...
# 4      ['First', ',', 'prepare', 'a', 'port', ',', 'l...
# ...                                                  ...
# 46312  ['Many', 'people', 'enjoy', 'a', 'game', 'in',...
# 46313  ['Marijuana', 'Legalization', '7', '/', '22', ...
# 46314  ['Some', 'patients', 'are', 'suffering', 'from...
# 46315  ['My', 'house', 'looks', 'amazing', 'and', 'mo...
# 46316  ['History', 'and', 'Geography', 'aopsule', 'My...
#
# [46230 rows x 8 columns]

# %% [markdown]
# # Binary Search Algorithm

# %%
#binary search for strings
def binarySearchArr(arr, x):
    l = 0
    r = len(arr)
    while (l <= r):
        m = l + ((r - l) // 2)
 
        res = (x == arr[m])
        # Check if x is present at mid
        if (res == True):
            return m
 
        # If x greater, ignore left half
    #problem is here
        elif (res == False):
            if (x>arr[m]):
                l = m+1
            elif (x<arr[m]):
                r=m-1
        # If x is smaller, ignore right half
    return -1

# %% [markdown]
# # Defining Functions

# %%
# function that finds the unique values in a list
def get_uniques(x):
    return list(x.unique())

# %% [markdown]
# # Seperating anon_ids by language

# %%
# creating a list of all the different languages
langs=[]
for i in student.native_language:
    lang=i
    if lang not in langs:
        langs.append(lang)

# %%
#This groups the anon_ids by their native language
count=0
lang_ids={}
for y in langs:
    count=0
    ids=[]
    key=y
    for i in student.anon_id:
        if (student.at[count, 'native_language'] == y):
            val=i
            ids.append(val)
        count=count+1
    lang_ids.update({key: ids})

# %%
print(langs)
# Out:
# ['Arabic', 'Nepali', 'Korean', 'Chinese', 'Russian', 'Turkish', 'French', 'Other', 'Japanese', 'Spanish', 'Thai', 'Portuguese', 'Taiwanese', 'English', 'Mongol', 'Italian', 'Vietnamese', 'Polish', 'German', 'Swedish', 'Hebrew', 'Farsi', 'Romanian', 'Indonesian', 'Suundi', 'Azerbaijani', 'Swahili', 'Hindi', 'Russian,Ukrainian', 'Montenegrin', 'Zulu']

# %%
#shows how many particpants are in each language
lang_counts=student.groupby('native_language').count().drop(columns=['gender','course_history','age'])
lang_counts
# Out:
#                    anon_id
# native_language
# Arabic                 465
# Azerbaijani              2
# Chinese                249
# English                  2
# Farsi                    4
# French                  13
# German                   3
# Hebrew                   6
# Hindi                    1
# Indonesian               2
# Italian                 12
# Japanese                81
# Korean                 245
# Mongol                   3
# Montenegrin              1
# Nepali                   1
# Other                   23
# Polish                   2
# Portuguese              20
# Romanian                 1
# Russian                 12
# Russian,Ukrainian        1
# Spanish                 66
# Suundi                   1
# Swahili                  1
# Swedish                  1
# Taiwanese               12
# Thai                    31
# Turkish                 47
# Vietnamese               4
# Zulu                     1

# %%
len(lang_ids)
# Out:
# 31

# %% [markdown]
# # Merging the two datasets

# %%
merge_ans=answer[['anon_id','course_id']]
student_merge=student.drop(columns=['course_history'])
# Out:
#       anon_id course_id
# 0         eq0       149
# 1         am8       149
# 2         dk5       115
# 3         dk5       115
# 4         ad1       115
# ...       ...       ...
# 46312     dr8      1050
# 46313     fv1      1045
# 46314     fo1      1045
# 46315     ge8      1033
# 46316     ge8      1033
#
# [46230 rows x 2 columns]

# %%
student_ans=student_merge.merge(answer,on='anon_id').astype({'course_id':'int64'})

# %%
stu_ans_crs=student_ans.merge(course_, on='course_id')

# %%
stu_ans_crs
# Out:
#       anon_id   gender native_language   age answer_id question_id  course_id  \
# 0         do6   Female         Russian  31.0       150           4        117
# 1         do6   Female         Russian  31.0      1221          97        117
# 2         do6   Female         Russian  31.0      1957         189        117
# 3         do6   Female         Russian  31.0      2164         190        117
# 4         bv5     Male          Arabic  21.0       151           4        117
# ...       ...      ...             ...   ...       ...         ...        ...
# 46225     cy7   Female          Korean   NaN     47682        6066       1034
# 46226     fp7   Female         Turkish   NaN     47823        6066       1034
# 46227     fq6     Male         Chinese   NaN     47824        6066       1034
# 46228     di6     Male         Chinese   NaN     47787        6066       1034
# 46229     fm3  Unknown          Arabic   NaN     47725        6066       1034
#
#       version text_len                                               text  \
# 0           1      299  Some people prefer eat out and some like doing...
# 1           1      288  My opinion is that a person does need educatio...
# 2           1      321  There are two national rooms in the Cathedral ...
# 3           1      464  There are two nation rooms in the Cathedral of...
# 4           1      315  "Not all learning takes place in the classroom...
# ...       ...      ...                                                ...
# 46225       1       10  1. emphasis\n2. appropriate\n3. requires\n4. a...
# 46226       1       10  1.emphasis \n2.appropriate\n3.requires\n4.anal...
# 46227       1       10  1.emphasis\n2.appropriate\n3.requires\n4.analy...
# 46228       1       10  1 emphasis\n2 normal\n3 requires\n4 analyze\n5...
# 46229       1       10  1- emphasis\n2- appropriate\n3- requires\n4- a...
#
#                                                   tokens  level_id
# 0      ['Some', 'people', 'prefer', 'eat', 'out', 'an...         5
# 1      ['My', 'opinion', 'is', 'that', 'a', 'person',...         5
# 2      ['There', 'are', 'two', 'national', 'rooms', '...         5
# 3      ['There', 'are', 'two', 'nation', 'rooms', 'in...         5
# 4      ['``', 'Not', 'all', 'learning', 'takes', 'pla...         5
# ...                                                  ...       ...
# 46225  ['1', '.', 'emphasis', '2', '.', 'appropriate'...         3
# 46226  ['1', '.', 'emphasis', '2', '.', 'appropriate'...         3
# 46227  ['1', '.', 'emphasis', '2', '.', 'appropriate'...         3
# 46228  ['1', 'emphasis', '2', 'normal', '3', 'require...         3
# 46229  ['1', '-', 'emphasis', '2', '-', 'appropriate'...         3
#
# [46230 rows x 12 columns]

# %%
sac_lvls=stu_ans_crs[['anon_id','native_language','level_id']]
sac_lvls
# Out:
#       anon_id native_language  level_id
# 0         do6         Russian         5
# 1         do6         Russian         5
# 2         do6         Russian         5
# 3         do6         Russian         5
# 4         bv5          Arabic         5
# ...       ...             ...       ...
# 46225     cy7          Korean         3
# 46226     fp7         Turkish         3
# 46227     fq6         Chinese         3
# 46228     di6         Chinese         3
# 46229     fm3          Arabic         3
#
# [46230 rows x 3 columns]

# %% [markdown]
# # Finiding who is in all three levels

# %% [markdown]
# first limit to list of who is in all three levels
# then run them into a dictionary based on their language (lang list as keys)

# %%
# from other notebook
# this code gets how many times an id appeared (n_anon_ids) as well as an array of what levels they participated in (lvl_nums)
clean_ids_lvl_loose=final_loose.groupby('anon_id').agg(
    n_anon_ids_loose=('level_id', 'nunique'),
    lvl_nums_loose=('level_id', get_uniques)
)

#changes the clean_ids_lvl's index so we can access the anon_id easier
ind_loose= clean_ids_lvl_loose.reset_index()
ind_loose

#seperates into all three
ind=0
all_three_loose=[]
append=''
for i in ind_loose.anon_id:
    if ind_loose.iat[ind, 1]==3:
        append=ind_loose.at[ind,'anon_id']
        all_three_loose.append(append)
    ind=ind+1

len(all_three_loose)

# %%
lvl_list=sac_lvls.groupby('anon_id').agg(n_uniq=('level_id','nunique'), lvl_nums=('level_id',get_uniques))
lvl_list=lvl_list.reset_index()

# %%
all_three=[]
ind=0
for i in lvl_list.anon_id:
    if lvl_list.iat[ind, 1]==3:
        append=lvl_list.at[ind, 'anon_id']
        all_three.append(append)
    ind+=1
len(all_three)
# Out:
# 149

# %%
print(lvl_list)
# Out:
#      anon_id  n_uniq lvl_nums
# 0        aa0       1      [5]
# 1        aa1       2   [4, 3]
# 2        aa2       2   [4, 3]
# 3        aa3       1      [4]
# 4        aa5       1      [4]
# ...      ...     ...      ...
# 1172     hb7       2   [5, 4]
# 1173     hb8       2   [3, 4]
# 1174     hb9       2   [5, 4]
# 1175     hc0       2   [4, 5]
# 1176     hc1       1      [5]
#
# [1177 rows x 3 columns]

# %%
print(sac_lvls)
# Out:
#       anon_id native_language  level_id
# 0         do6         Russian         5
# 1         do6         Russian         5
# 2         do6         Russian         5
# 3         do6         Russian         5
# 4         bv5          Arabic         5
# ...       ...             ...       ...
# 46225     cy7          Korean         3
# 46226     fp7         Turkish         3
# 46227     fq6         Chinese         3
# 46228     di6         Chinese         3
# 46229     fm3          Arabic         3
#
# [46230 rows x 3 columns]

# %%
all_anon=[]
for i in sac_lvls.anon_id:
    all_anon.append(i)
len(all_anon)
# Out:
# 46230

# %%
# gets unique ids
uanon=[]
index=0
for i in all_anon:
    if all_anon[index] not in uanon:
        uanon.append(all_anon[index])
    index=index+1
uanon.sort()

# %%
lang_dict_in34lim={} #creates a dictionary where we can store the anon_id as the key and the language as the definition
for i in in34_lim:
    df_index=binarySearchArr(anon_lim,i) #utilizing binary search 
    qindex=binarySearchArr(uanon_lim, i)
    
    key=sorted_lim.at[df_index,'anon_id'] #adding the anon_id as a key
    val=sorted_lim.at[df_index,'L1'] #adding the language as the definition of that anon_ids
    val2=qcount_lim.at[qindex,'Number of Questions']
    
    if key not in lang_dict_in34lim.keys():#to account for duplicate entires. if the anon_id is not already a key, it will be added
        lang_dict_in34lim.update({key: [val,val2] })
print(lang_dict_in34lim)

# %%
lang_dict_all=dict.fromkeys(langs)
for i in all_three:
    df_index=binarySearchArr(uanon, i)
   # qindex=binarySearchArr(uanon, i)
    
    val=lvl_list.at[df_index,'anon_id']
# Out:
#   File "<ipython-input-75-eb74d6865dbd>", line 6
#     key=
#         ^
# SyntaxError: invalid syntax

# %%
sorted_sac=sac_lvls.sort_values(by=['anon_id']).reset_index(drop=True)
print(sorted_sac)
# Out:
#       anon_id native_language  level_id
# 0         aa0         Spanish         5
# 1         aa0         Spanish         5
# 2         aa0         Spanish         5
# 3         aa0         Spanish         5
# 4         aa0         Spanish         5
# ...       ...             ...       ...
# 46225     hc1          Korean         5
# 46226     hc1          Korean         5
# 46227     hc1          Korean         5
# 46228     hc1          Korean         5
# 46229     hc1          Korean         5
#
# [46230 rows x 3 columns]

# %%
lang_dict_all=dict.fromkeys(langs)

for key in lang_dict_all.keys():
   # index=0
    for i in uanon:
        df_ind=binarySearchArr(all_anon,i)
        if (key==sorted_sac.at[df_ind,'native_language']):
            val=sorted_sac.at[df_ind,'anon_id']
            lang_dict_all.update({key:[val]})
print(lang_dict_all)
# Out:
# {'Arabic': ['hb9'], 'Nepali': None, 'Korean': ['hc1'], 'Chinese': ['gz5'], 'Russian': ['gi7'], 'Turkish': ['ha9'], 'French': ['hb6'], 'Other': ['gw3'], 'Japanese': ['hb7'], 'Spanish': ['gx0'], 'Thai': ['gy1'], 'Portuguese': ['gx6'], 'Taiwanese': ['hc0'], 'English': ['ez7'], 'Mongol': ['gg5'], 'Italian': ['fd7'], 'Vietnamese': ['cb5'], 'Polish': ['bg6'], 'German': ['fh4'], 'Swedish': ['fo5'], 'Hebrew': ['fq1'], 'Farsi': ['gy9'], 'Romanian': ['bm1'], 'Indonesian': ['fc5'], 'Suundi': ['cl9'], 'Azerbaijani': ['fs5'], 'Swahili': ['ee8'], 'Hindi': ['am0'], 'Russian,Ukrainian': ['am2'], 'Montenegrin': ['ce1'], 'Zulu': ['as8']}

# %%
all_anon.sort()
all_anon
# Out:
# ['aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa0',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa1',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa2',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa3',
#  'aa5',
#  'aa5',
#  'aa5',
#  'aa5',
#  'aa5',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa8',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'aa9',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab1',
#  'ab2',
#  'ab2',
#  'ab2',
#  'ab2',
#  'ab2',
#  'ab2',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab6',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ab8',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac2',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac3',
#  'ac4',
#  'ac4',
#  'ac4',
#  'ac4',
#  'ac4',
#  'ac4',
#  'ac4',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac5',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac6',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac7',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac8',
#  'ac9',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad1',
#  'ad2',
#  'ad2',
#  'ad2',
#  'ad2',
#  'ad2',
#  'ad2',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad3',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad4',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  'ad5',
#  ...]

# %%
uanon=uanon.sort()
uanon
# Out:
# ['aa0',
#  'aa1',
#  'aa2',
#  'aa3',
#  'aa5',
#  'aa8',
#  'aa9',
#  'ab1',
#  'ab2',
#  'ab6',
#  'ab8',
#  'ac2',
#  'ac3',
#  'ac4',
#  'ac5',
#  'ac6',
#  'ac7',
#  'ac8',
#  'ac9',
#  'ad1',
#  'ad2',
#  'ad3',
#  'ad4',
#  'ad5',
#  'ad7',
#  'ad8',
#  'ad9',
#  'ae0',
#  'ae2',
#  'ae3',
#  'ae4',
#  'ae5',
#  'ae9',
#  'af0',
#  'af1',
#  'af2',
#  'af3',
#  'af4',
#  'af7',
#  'ag0',
#  'ag2',
#  'ag3',
#  'ag4',
#  'ag5',
#  'ag6',
#  'ag7',
#  'ag8',
#  'ag9',
#  'ah0',
#  'ah1',
#  'ah4',
#  'ah5',
#  'ah6',
#  'ah8',
#  'ah9',
#  'ai0',
#  'ai1',
#  'ai3',
#  'ai4',
#  'ai7',
#  'aj0',
#  'aj1',
#  'aj3',
#  'aj5',
#  'aj6',
#  'aj7',
#  'aj8',
#  'aj9',
#  'ak0',
#  'ak1',
#  'ak5',
#  'ak7',
#  'al0',
#  'al1',
#  'al2',
#  'al5',
#  'al9',
#  'am0',
#  'am1',
#  'am2',
#  'am3',
#  'am5',
#  'am6',
#  'am7',
#  'am8',
#  'am9',
#  'an1',
#  'an2',
#  'an4',
#  'an5',
#  'an7',
#  'an9',
#  'ao0',
#  'ao1',
#  'ao2',
#  'ao3',
#  'ao4',
#  'ao5',
#  'ao6',
#  'ao8',
#  'ap0',
#  'ap2',
#  'ap4',
#  'ap5',
#  'ap6',
#  'ap7',
#  'ap8',
#  'aq0',
#  'aq1',
#  'aq2',
#  'aq4',
#  'aq5',
#  'aq7',
#  'aq9',
#  'ar0',
#  'ar2',
#  'ar5',
#  'ar8',
#  'ar9',
#  'as0',
#  'as1',
#  'as2',
#  'as4',
#  'as5',
#  'as7',
#  'as8',
#  'at1',
#  'at2',
#  'at3',
#  'at4',
#  'at6',
#  'at7',
#  'at8',
#  'at9',
#  'au2',
#  'au3',
#  'au5',
#  'au6',
#  'au7',
#  'au8',
#  'au9',
#  'av0',
#  'av4',
#  'av7',
#  'av8',
#  'av9',
#  'aw2',
#  'aw3',
#  'aw4',
#  'aw5',
#  'aw6',
#  'aw9',
#  'ax0',
#  'ax2',
#  'ax3',
#  'ax4',
#  'ax5',
#  'ax6',
#  'ax7',
#  'ax9',
#  'ay0',
#  'ay1',
#  'ay2',
#  'ay3',
#  'ay4',
#  'ay7',
#  'ay8',
#  'az0',
#  'az2',
#  'az3',
#  'az4',
#  'az5',
#  'az6',
#  'az8',
#  'az9',
#  'ba0',
#  'ba1',
#  'ba3',
#  'ba4',
#  'ba5',
#  'ba9',
#  'bb0',
#  'bb1',
#  'bb4',
#  'bb5',
#  'bb6',
#  'bb9',
#  'bc0',
#  'bc1',
#  'bc2',
#  'bc3',
#  'bc4',
#  'bd0',
#  'bd1',
#  'bd3',
#  'bd4',
#  'bd7',
#  'bd8',
#  'be1',
#  'be2',
#  'be4',
#  'be7',
#  'be8',
#  'bf0',
#  'bf1',
#  'bf2',
#  'bf3',
#  'bf5',
#  'bf7',
#  'bf8',
#  'bf9',
#  'bg0',
#  'bg1',
#  'bg2',
#  'bg3',
#  'bg5',
#  'bg6',
#  'bg7',
#  'bh0',
#  'bh1',
#  'bh2',
#  'bh3',
#  'bh4',
#  'bh7',
#  'bh8',
#  'bh9',
#  'bi0',
#  'bi1',
#  'bi3',
#  'bi4',
#  'bi5',
#  'bi6',
#  'bi7',
#  'bi8',
#  'bi9',
#  'bj0',
#  'bj1',
#  'bj2',
#  'bj4',
#  'bj6',
#  'bj8',
#  'bj9',
#  'bk0',
#  'bk2',
#  'bk5',
#  'bk7',
#  'bk8',
#  'bl0',
#  'bl2',
#  'bl3',
#  'bl4',
#  'bl5',
#  'bl6',
#  'bl7',
#  'bl8',
#  'bl9',
#  'bm0',
#  'bm1',
#  'bm3',
#  'bm4',
#  'bm5',
#  'bm6',
#  'bm7',
#  'bm8',
#  'bm9',
#  'bn1',
#  'bn3',
#  'bn5',
#  'bn6',
#  'bn7',
#  'bo0',
#  'bo1',
#  'bo4',
#  'bo5',
#  'bo8',
#  'bo9',
#  'bp2',
#  'bp4',
#  'bp5',
#  'bp6',
#  'bp8',
#  'bp9',
#  'bq0',
#  'bq3',
#  'bq4',
#  'bq6',
#  'bq8',
#  'bq9',
#  'br1',
#  'br2',
#  'br3',
#  'br4',
#  'br5',
#  'br6',
#  'br7',
#  'br8',
#  'br9',
#  'bs0',
#  'bs1',
#  'bs2',
#  'bs3',
#  'bs5',
#  'bs6',
#  'bs8',
#  'bs9',
#  'bt1',
#  'bt2',
#  'bt7',
#  'bt8',
#  'bu0',
#  'bu1',
#  'bu3',
#  'bu4',
#  'bu6',
#  'bu8',
#  'bu9',
#  'bv0',
#  'bv1',
#  'bv2',
#  'bv4',
#  'bv5',
#  'bv8',
#  'bv9',
#  'bw1',
#  'bw2',
#  'bw3',
#  'bw4',
#  'bw5',
#  'bw6',
#  'bw9',
#  'bx3',
#  'bx4',
#  'bx5',
#  'bx6',
#  'bx9',
#  'by1',
#  'by2',
#  'by3',
#  'by4',
#  'by5',
#  'by6',
#  'by8',
#  'by9',
#  'bz1',
#  'bz2',
#  'bz3',
#  'bz5',
#  'bz9',
#  'ca0',
#  'ca4',
#  'ca5',
#  'ca6',
#  'ca7',
#  'ca8',
#  'ca9',
#  'cb0',
#  'cb1',
#  'cb2',
#  'cb3',
#  'cb5',
#  'cb7',
#  'cb8',
#  'cb9',
#  'cc1',
#  'cc4',
#  'cc6',
#  'cc7',
#  'cd2',
#  'cd3',
#  'cd4',
#  'cd6',
#  'cd8',
#  'ce1',
#  'ce2',
#  'ce3',
#  'ce6',
#  'ce7',
#  'ce8',
#  'cf0',
#  'cf1',
#  'cf2',
#  'cf3',
#  'cf6',
#  'cf7',
#  'cf9',
#  'cg1',
#  'cg2',
#  'cg3',
#  'cg6',
#  'cg8',
#  'cg9',
#  'ch0',
#  'ch1',
#  'ch2',
#  'ch4',
#  'ch5',
#  'ch7',
#  'ch9',
#  'ci0',
#  'ci1',
#  'ci2',
#  'ci3',
#  'ci4',
#  'ci5',
#  'ci6',
#  'ci7',
#  'ci9',
#  'cj2',
#  'cj3',
#  'cj5',
#  'cj7',
#  'cj8',
#  'ck0',
#  'ck1',
#  'ck2',
#  'ck3',
#  'ck4',
#  'ck6',
#  'ck7',
#  'ck9',
#  'cl1',
#  'cl2',
#  'cl3',
#  'cl4',
#  'cl5',
#  'cl6',
#  'cl7',
#  'cl9',
#  'cm2',
#  'cm4',
#  'cm7',
#  'cm8',
#  'cm9',
#  'cn0',
#  'cn1',
#  'cn2',
#  'cn3',
#  'cn4',
#  'cn7',
#  'cn8',
#  'cn9',
#  'co0',
#  'co1',
#  'co2',
#  'co4',
#  'co5',
#  'co8',
#  'co9',
#  'cp0',
#  'cp2',
#  'cp3',
#  'cp4',
#  'cp5',
#  'cp6',
#  'cp7',
#  'cp8',
#  'cq0',
#  'cq1',
#  'cq2',
#  'cq4',
#  'cq6',
#  'cq8',
#  'cq9',
#  'cr1',
#  'cr3',
#  'cr4',
#  'cr8',
#  'cr9',
#  'cs0',
#  'cs1',
#  'cs3',
#  'cs4',
#  'cs5',
#  'cs6',
#  'cs7',
#  'cs8',
#  'cs9',
#  'ct0',
#  'ct1',
#  'ct4',
#  'ct5',
#  'ct9',
#  'cu0',
#  'cu1',
#  'cu2',
#  'cu4',
#  'cu6',
#  'cu8',
#  'cu9',
#  'cv1',
#  'cv2',
#  'cv3',
#  'cv5',
#  'cv7',
#  'cv8',
#  'cw0',
#  'cw1',
#  'cw2',
#  'cw4',
#  'cw6',
#  'cw7',
#  'cw8',
#  'cw9',
#  'cx0',
#  'cx4',
#  'cx5',
#  'cx6',
#  'cx8',
#  'cx9',
#  'cy1',
#  'cy2',
#  'cy3',
#  'cy5',
#  'cy6',
#  'cy7',
#  'cz2',
#  'cz3',
#  'cz4',
#  'cz6',
#  'cz7',
#  'cz8',
#  'cz9',
#  'da0',
#  'da3',
#  'da6',
#  'da7',
#  'da8',
#  'da9',
#  'db1',
#  'db2',
#  'db3',
#  'db4',
#  'db5',
#  'db6',
#  'db8',
#  'db9',
#  'dc0',
#  'dc1',
#  'dc2',
#  'dc6',
#  'dd1',
#  'dd3',
#  'dd4',
#  'dd5',
#  'dd6',
#  'dd9',
#  'de1',
#  'de2',
#  'de4',
#  'de5',
#  'de6',
#  'de7',
#  'df0',
#  'df2',
#  'df3',
#  'df4',
#  'df6',
#  'df7',
#  'df9',
#  'dg0',
#  'dg2',
#  'dg3',
#  'dg5',
#  'dg6',
#  'dg7',
#  'dg9',
#  'dh0',
#  'dh1',
#  'dh2',
#  'dh6',
#  'dh7',
#  'dh8',
#  'dh9',
#  'di0',
#  'di1',
#  'di2',
#  'di3',
#  'di6',
#  'di7',
#  'di8',
#  'dj0',
#  'dj3',
#  'dj5',
#  'dj6',
#  'dj7',
#  'dj8',
#  'dj9',
#  'dk0',
#  'dk3',
#  'dk5',
#  'dk6',
#  'dk9',
#  'dl1',
#  'dl2',
#  'dl3',
#  'dl5',
#  'dl7',
#  'dl8',
#  'dl9',
#  'dm2',
#  'dm3',
#  'dm4',
#  'dm8',
#  'dn0',
#  'dn1',
#  'dn2',
#  'dn4',
#  'dn5',
#  'dn6',
#  'dn7',
#  'dn8',
#  'do0',
#  'do1',
#  'do3',
#  'do4',
#  'do5',
#  'do6',
#  'do7',
#  'do9',
#  'dp1',
#  'dp2',
#  'dp3',
#  'dp4',
#  'dp5',
#  'dp7',
#  'dp9',
#  'dq0',
#  'dq4',
#  'dq7',
#  'dq9',
#  'dr0',
#  'dr1',
#  'dr2',
#  'dr3',
#  'dr5',
#  'dr8',
#  'ds0',
#  'ds2',
#  'ds3',
#  'ds5',
#  'ds6',
#  'ds8',
#  'ds9',
#  'dt0',
#  'dt1',
#  'dt3',
#  'dt4',
#  'dt5',
#  'dt6',
#  'dt8',
#  'du2',
#  'du3',
#  'du4',
#  'du5',
#  'du6',
#  'du7',
#  'du8',
#  'du9',
#  'dv0',
#  'dv1',
#  'dv4',
#  'dv7',
#  'dv8',
#  'dv9',
#  'dw0',
#  'dw2',
#  'dw3',
#  'dw6',
#  'dw7',
#  'dw9',
#  'dx1',
#  'dx2',
#  'dx3',
#  'dx4',
#  'dx5',
#  'dx6',
#  'dx7',
#  'dx8',
#  'dx9',
#  'dy0',
#  'dy4',
#  'dy7',
#  'dz0',
#  'dz1',
#  'dz3',
#  'dz5',
#  'dz7',
#  'dz8',
#  'dz9',
#  'ea0',
#  'ea2',
#  'ea3',
#  'ea4',
#  'ea5',
#  'ea7',
#  'ea9',
#  'eb3',
#  'eb4',
#  'eb5',
#  'eb6',
#  'eb7',
#  'eb9',
#  'ec0',
#  'ec1',
#  'ec5',
#  'ec7',
#  'ec9',
#  'ed1',
#  'ed2',
#  'ed3',
#  'ed7',
#  'ed8',
#  'ee1',
#  'ee3',
#  'ee4',
#  'ee5',
#  'ee7',
#  'ee8',
#  'ee9',
#  'ef0',
#  'ef1',
#  'ef2',
#  'ef3',
#  'ef4',
#  'ef6',
#  'ef9',
#  'eg2',
#  'eg3',
#  'eg4',
#  'eg5',
#  'eg8',
#  'eh0',
#  'eh2',
#  'eh4',
#  'eh6',
#  'eh7',
#  'eh8',
#  'eh9',
#  'ei0',
#  'ei2',
#  'ei3',
#  'ei5',
#  'ei7',
#  'ei8',
#  'ej0',
#  'ej1',
#  'ej2',
#  'ej5',
#  'ej8',
#  'ej9',
#  'ek1',
#  'ek3',
#  'ek5',
#  'ek6',
#  'ek7',
#  'ek8',
#  'el0',
#  'el2',
#  'el3',
#  'el5',
#  'el7',
#  'el8',
#  'el9',
#  'em0',
#  'em1',
#  'em5',
#  'em6',
#  'em7',
#  'em8',
#  'en1',
#  'en2',
#  'en3',
#  'en4',
#  'en8',
#  'en9',
#  'eo1',
#  'eo2',
#  'eo5',
#  'eo8',
#  'ep1',
#  'ep2',
#  'ep4',
#  'ep6',
#  'eq0',
#  'eq1',
#  'eq2',
#  'eq4',
#  'eq6',
#  'eq8',
#  'er2',
#  'er3',
#  'er4',
#  'er5',
#  'er9',
#  'es0',
#  'es2',
#  'es4',
#  'es5',
#  'es6',
#  'es7',
#  'es9',
#  'et0',
#  'et1',
#  'et3',
#  'et4',
#  'et5',
#  'et6',
#  'et8',
#  'eu0',
#  'eu1',
#  'eu2',
#  'eu5',
#  'eu6',
#  'eu7',
#  'eu8',
#  'eu9',
#  'ev0',
#  'ev4',
#  'ev5',
#  'ev6',
#  'ev7',
#  'ev9',
#  'ew2',
#  'ew4',
#  'ew6',
#  'ew7',
#  'ew8',
#  'ew9',
#  'ex0',
#  'ex3',
#  'ex6',
#  'ex7',
#  'ex9',
#  'ey0',
#  'ey2',
#  'ey3',
#  'ey4',
#  'ey8',
#  'ey9',
#  'ez2',
#  'ez3',
#  'ez5',
#  'ez6',
#  'ez7',
#  'ez8',
#  'fa0',
#  'fa2',
#  'fa4',
#  'fa5',
#  'fa6',
#  'fa9',
#  'fb1',
#  'fb3',
#  'fb4',
#  'fb5',
#  'fb8',
#  'fb9',
#  'fc0',
#  'fc1',
#  'fc5',
#  'fc7',
#  'fc9',
#  'fd1',
#  'fd2',
#  'fd3',
#  'fd6',
#  'fd7',
#  'fd8',
#  'fe0',
#  'fe1',
#  'fe2',
#  'fe3',
#  'fe4',
#  'fe5',
#  'fe7',
#  'fe9',
#  'ff0',
#  'ff1',
#  'ff2',
#  'ff3',
#  'ff4',
#  'ff6',
#  'fg0',
#  'fg2',
#  'fg7',
#  'fg8',
#  'fg9',
#  'fh1',
#  'fh2',
#  'fh4',
#  'fh5',
#  'fh7',
#  'fh9',
#  'fi1',
#  'fi4',
#  'fi5',
#  'fi6',
#  'fj0',
#  'fj2',
#  'fj4',
#  'fj7',
#  'fj8',
#  'fj9',
#  'fk0',
#  'fk1',
#  'fk2',
#  'fk3',
#  'fk5',
#  'fk7',
#  'fk8',
#  'fk9',
#  'fl0',
#  'fl4',
#  'fl5',
#  'fl6',
#  'fm1',
#  'fm2',
#  'fm3',
#  'fm4',
#  'fm5',
#  'fm6',
#  'fm9',
#  'fn0',
#  'fn1',
#  'fn2',
#  'fn5',
#  'fn8',
#  'fo0',
#  'fo1',
#  'fo2',
#  'fo3',
#  'fo4',
#  'fo5',
#  'fo7',
#  'fo8',
#  'fp1',
#  'fp2',
#  'fp4',
#  'fp5',
#  'fp6',
#  'fp7',
#  'fp9',
#  'fq0',
#  'fq1',
#  'fq5',
#  'fq6',
#  'fq8',
#  'fr0',
#  'fr1',
#  'fr2',
#  'fr4',
#  'fr5',
#  'fr6',
#  'fr9',
#  'fs0',
#  'fs1',
#  'fs3',
#  'fs4',
#  'fs5',
#  'fs6',
#  'fs9',
#  'ft0',
#  'ft2',
#  'ft6',
#  'ft8',
#  'ft9',
#  'fu0',
#  'fu1',
#  'fu2',
#  'fu3',
#  'fu4',
#  'fu5',
#  'fu6',
#  'fu7',
#  'fu8',
#  'fv1',
#  'fv4',
#  'fv6',
#  'fv7',
#  'fv8',
#  'fv9',
#  'fw1',
#  'fw3',
#  'fw4',
#  'fw5',
#  'fw7',
#  'fw9',
#  'fx2',
#  'fx4',
#  'fx7',
#  'fx8',
#  'fx9',
#  'fy0',
#  'fy1',
#  'fy2',
#  'fy3',
#  'fy5',
#  'fy6',
#  'fy8',
#  'fz0',
#  ...]

# %%
# Out:
# {'Arabic': None,
#  'Nepali': None,
#  'Korean': None,
#  'Chinese': None,
#  'Russian': None,
#  'Turkish': None,
#  'French': None,
#  'Other': None,
#  'Japanese': None,
#  'Spanish': None,
#  'Thai': None,
#  'Portuguese': None,
#  'Taiwanese': None,
#  'English': None,
#  'Mongol': None,
#  'Italian': None,
#  'Vietnamese': None,
#  'Polish': None,
#  'German': None,
#  'Swedish': None,
#  'Hebrew': None,
#  'Farsi': None,
#  'Romanian': None,
#  'Indonesian': None,
#  'Suundi': None,
#  'Azerbaijani': None,
#  'Swahili': None,
#  'Hindi': None,
#  'Russian,Ukrainian': None,
#  'Montenegrin': None,
#  'Zulu': None}

# %%
for key in dict:
    if matches id, add to dict

if the native lang is the same as the key, append it to the list, if not skip it for now
