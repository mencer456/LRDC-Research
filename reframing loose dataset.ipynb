# %%
#importing libraries
import pandas as pd

# %%
df=pd.read_csv('original-sheets\Responses-Loose.csv')
df34=df.query('level_id==3 or level_id==4')

# %%
df34
# Out:
#      3Langs   Item  answer_id anon_id       L1   gender  course_id  level_id  \
# 18        Y    C96     1144.0     bd7  Chinese   Female      114.0       4.0
# 19        Y    C97     1147.0     bo8  Chinese   Female      114.0       4.0
# 20        Y   K115     1148.0     fa0   Korean     Male      114.0       4.0
# 21        Y   K116     1151.0     eu6   Korean     Male      114.0       4.0
# 22        Y     S9     1146.0     gq4  Spanish   Female      114.0       4.0
# ...     ...    ...        ...     ...      ...      ...        ...       ...
# 1805      Y  K3544    47845.0     ec1   Korean   Female     1048.0       4.0
# 1806      Y   S779    47882.0     cq1  Spanish   Female     1048.0       4.0
# 1807      Y  C3207    48246.0     bv8  Chinese  Unknown     1043.0       4.0
# 1808      Y  K3559    48254.0     dr8   Korean   Female     1043.0       4.0
# 1809      Y   S781    48252.0     bl3  Spanish   Female     1043.0       4.0
#
# ...
